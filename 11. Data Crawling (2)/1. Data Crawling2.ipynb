# %% [markdown]
# # 라이브러리 설치

# %%
# !pip install selenium

# %% [markdown]
# # Selenium 연습

# %% [markdown]
# ## By.Name 구문

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

# ChromeDriver의 경로를 지정하고, WebDriver 인스턴스를 생성합니다.
driver = webdriver.Chrome() #C드라이브 Windows 폴더에 넣었기 때문에 아무것도 입력하지 않아도 된다
#driver 변수에 webdriver 객체를 넣는다

# 지마켓의 메인 페이지를 엽니다.
driver.get('https://www.gmarket.co.kr') #webdriver 객체가 메소드 get을 통해 URL을 탐색할 수 있다

# 검색어를 입력할 수 있는 input 요소를 찾습니다. (GMarket의 경우 <input name="keyword" title="검색창" class="form__input" ...꼴이다)
search_box = driver.find_element(By.NAME, 'keyword')
#By.Name은 name속성을 가지고 탐색하는 것이다

# 검색어를 입력하고, Enter 키를 눌러 검색을 실행합니다. (Selenium은 찾은 것을 가지고 또 크롤링할 수 있다)
search_box.send_keys('손풍기')       #input 요소(지금은 search_box)에 '손풍기'라는 입력을 보낸다, 단 입력에 그치므로
search_box.send_keys(Keys.RETURN)   #엔터 역할을 하는 Keys.Return이 필요하다

# 작업이 끝나면 WebDriver를 종료하여 브라우저 창을 닫습니다.
driver.quit()

# %% [markdown]
# ## By.CSS_SELECTOR 구문

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

title_list = list()

# ChromeDriver의 경로를 지정하고, WebDriver 인스턴스를 생성합니다.
driver = webdriver.Chrome()

# 지마켓의 베스트 페이지를 엽니다.
driver.get('https://www.gmarket.co.kr/n/best')

# 상품명을 입력 받아 item_list 변수에 저장합니다.
item_list = driver.find_elements(By.CSS_SELECTOR, 'a.itemname') # By.CSS_SELECTOR: 키워드에 해당하는 객체를 반환, element's'이므로 여러 개 반환

for item in item_list:
    title_list.append(item.text)

driver.quit()

# %%
print(title_list)
# Out:
# ['[크리넥스]크리넥스 안심클래식 키친타올 120매 4롤4팩', '[해듬뿍]완도산 활전복 실속세트 쿠폰가 22750원 대전복 10-12미 1KG 횟감용', '[락토핏]종근당건강 유산균 락토핏 골드 50포 3통(150일분) +30포 증정', '[햇반]CJ 햇반 210g 36개 1박스', '[깨끗한나라]깨끗한나라 순수시그니처 화장지 브라운 30m 30롤 2팩', '[좋은느낌]좋은느낌 입는오버나이트 중/소/대형 8PX4 팩외+증정 /여름생리대', '[앤드지바이지오지아][앤드지] 슬림핏 사이드 밴딩 워셔블 여름 슬랙스 6종 택1(BED2PP1003)', '[베베쿡]베베쿡 배도라지 사르르쿵 외 인기 간식특가전', '여수사나이 별미 열무물김치 2kg+2kg / 국내산 / 당일생산', '[동국제약]동국제약 마데카솔 연고 8g 2개+메디패치 습윤밴드 33매 1개', '[CJ제일제당]맛밤 60g x20개', '[스팸]스팸 클래식 200g x9개', '[웅진]광복절15%/ 815콜라 250ml 60캔 /최종16300원(8150원 x 2박스)(30캔X2박스)', '[하비비]청개구리 자동 변기 클리너 세정제 6개 (12개월분)', '아리울 떡 공방 2세트시 2천원 할인 / 특가 굳지않는 모듬 꿀떡 1
�마 핸드워시 3.5L 레몬향+증정)레몬향 공병250ml 2개', '[서울우유]멸균우유 1000ml x 10입 (1박스)', '[촌아저씨]의성 옥자두 도담자두 추희자두 2kg 대과 (개당 110g내외)/냉장포장', '유명산지 거봉 1.5kg (박스)', '김소형 원방 흑염소 진액스틱 15g x 100포', '샤워때비누 900ml x 2개(사해+화산) + 핸드워시 리필 2개 증정', '[고려은단]멀티비타민 올인원 종합비타민 미네랄영양제 종합영양제 60정 x 3개 (6개월분) +쇼핑백 (소)', '[농심]신라면+안성탕면+너구리+짜파게티 20봉 +비비고사골곰탕 300g 선착순증정', '탑텐키즈 본사직영 | 미리 만나는 역시즌 특가 플리스/경량베스트 ...

# %% [markdown]
# # selenium 실행하고 상품명, 가격, 별점 정보 저장

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

#상품명, 가격, 별점 정보를 저장할 빈 리스트를 생성
title_list = list()
price_list = list()
star_list = list()

# ChromeDriver의 경로를 지정하고, WebDriver 인스턴스를 생성합니다.
driver = webdriver.Chrome()

# 지마켓의 메인 페이지를 엽니다.
driver.get('https://www.gmarket.co.kr')

# 검색어를 입력할 수 있는 input 요소를 찾습니다.
search_box = driver.find_element(By.NAME, 'keyword')

# 검색어를 입력하고, Enter 키를 눌러 검색을 실행합니다.
search_box.send_keys('손풍기')
search_box.send_keys(Keys.RETURN)

# 결과 페이지가 로드될 때까지 잠시 기다립니다.
driver.implicitly_wait(3)

# 정보를 담은 박스를 선택합니다.
search_results = driver.find_elements(By.CSS_SELECTOR, 'div.box__information') # tag는 '#' class는 '.'이다

for result in search_results:
    #만족도가 없을 수도 있기에 try except문을 활용
    try:
        title_element = result.find_element(By.CSS_SELECTOR, 'span.text__item')
        price_element = result.find_element(By.CSS_SELECTOR, 'div.box__price-seller > strong')
        star_element = result.find_element(By.CSS_SELECTOR, 'span.image__awards-points > span')
        title_list.append(title_element.text)
        price_list.append(price_element.text)
        star_list.append(star_element.text)
    except:
        pass
    
# 작업이 끝나면 WebDriver를 종료하여 브라우저 창을 닫습니다.
driver.quit()

# %% [markdown]
# # 데이터 프레임으로 저장하고 Excel 파일로 저장하기

# %%
import pandas as pd

gmarket_selenium_df = pd.DataFrame([title_list, price_list, star_list]).T

# %%
gmarket_selenium_df.columns = ['상품명', '판매가', '만족도']

# %%
gmarket_selenium_df
# Out:
#                                                   상품명     판매가           만족도
# 0                           카카오프렌즈 릴렉싱 소파 휴대용 선풍기 춘식이  29,900
# 1   3초 급속냉각 휴대용 손선풍기 핸디선풍기 에어컨선풍기 COOL-10 올 여름 시원~...  27,900
# 2                   1+1 휴대용 넥밴드 목 선풍기 목걸이 여름 목풍기 KC인증  26,900
# 3                           카카오프렌즈 릴렉싱 소파 휴대용 선풍기 라이언  29,900
# 4                       미니 신세대 목걸이 선풍기 USB 충전 휴대용 선풍기  28,750
# ..                                                ...     ...           ...
# 91   MACH 에어컨 넥 선풍기 목 넥밴드 쿨링 휴대용 미니 목풍기 목걸이 넥풍기 목에 거는  43,900  만족도 60% 입니다.
# 92  1+1(2개) 핸드선풍기 휴대용 무소음 BLDC 1초 급속냉각 미니 손 선풍기 ED...  55,800  만족도 96% 입니다.
# 93                       휴대용 미니 선풍기 탁상용 스탠드 무선 써큘레이터형  23,900  만족도 92% 입니다.
# 94                       휴대용 미니 선풍기 탁상용 스탠드 무선 써큘레이터형  23,900  만족도 98% 입니다.
# 95     1+1 휴대용 집게 선풍기 6인치대형팬 BLDC 탁상용 유모차선풍기 OEF-6FAN  27,900  만족도 90% 입니다.
#
# [96 rows x 3 columns]

# %%
def extract_comma(x):
    price = int(x.replace(",", "")) #replace로 쉼표까지 제거하고 int로 변환
    return price

# %%
gmarket_selenium_df['판매가'] = gmarket_selenium_df['판매가'].apply(extract_comma)

# %%
import re

def extract_stars(x):
    ext = re.findall("\d+%", x) # +는 한 번 이상 반복되는 것을 의미하는 메타 문자
                                # \d+ 로 연속된 숫자를 찾는다
                                 
    #데이터가 빈 경우가 있으므로 try, except문 사용
    try:
        stars = int(ext[0].replace('%', "")) #%를 제거한 뒤 int로 변환
    except:
        pass
    return stars if ext else None #데이터가 있을 경우 stars를 반환, 아닐 경우 None을 반환

# %%
gmarket_selenium_df['만족도'] = gmarket_selenium_df['만족도'].apply(extract_stars)

# %%
gmarket_selenium_df.dropna()
# Out:
#                                                   상품명    판매가   만족도
# 0      비즈 펠티어 냉각판 에어컨 휴대용 손선풍기 BZ-FH40 대용량배터리 4000mAh  49900  90.0
# 1                              카카오프렌즈 춘식이 수영장 크래들 선풍기  29900  98.0
# 2                    LOOC 룩 휴대용 선풍기 미니 손 핸디형 손풍기 - 블랙  15900  94.0
# 3       이지마켓 초강력미니선풍기 미니 손선풍기 에어컨손풍기 얼음이 내손안에 핸디써큘레이터  29900  92.0
# 4                      핸드팬 대용량 2600mAh 충전식 휴대용선풍기 화이트  14000  86.0
# ..                                                ...    ...   ...
# 86   MACH 에어컨 넥 선풍기 목 넥밴드 쿨링 휴대용 미니 목풍기 목걸이 넥풍기 목에 거는  43900  60.0
# 87  1+1(2개) 핸드선풍기 휴대용 무소음 BLDC 1초 급속냉각 미니 손 선풍기 ED...  55800  96.0
# 88                       휴대용 미니 선풍기 탁상용 스탠드 무선 써큘레이터형  23900  92.0
# 89                       휴대용 미니 선풍기 탁상용 스탠드 무선 써큘레이터형  23900  98.0
# 90     1+1 휴대용 집게 선풍기 6인치대형팬 BLDC 탁상용 유모차선풍기 OEF-6FAN  27900  90.0
#
# [91 rows x 3 columns]

# %%
gmarket_selenium_df = gmarket_selenium_df.dropna().reset_index().iloc[:, 1:] 
# dropna()로 결측치가 있는 열을 삭제 --> 인덱스가 도중에 비는 문제가 생길 수 있음
# reset_index()로 인덱스를 다시 설정
# iloc[:, 1:]로 기존 인덱스를 버리고 새로운 인덱스부터 뒤의 column들만 포함한 데이터 프레임을 반환

# %%
gmarket_selenium_df.to_excel('gmarket_handfan_stars.xlsx')
